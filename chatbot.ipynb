# %%
from groq import Groq
from dotenv import load_dotenv
import os

load_dotenv()

client = Groq(api_key=os.getenv("GROQ_API_KEY"))
conversation = []

print("🤖 Chatbot ready! Type 'quit' to exit\n")
conversation = [
    {
        "role": "system",
        "content": "You are a helpful AI tutor who teaches Gen AI concepts to beginners in a simple, friendly way. Keep answers short and use examples."
    }
]

while True:
    user_input = input("You: ")
    
    if user_input.lower() == "quit":
        print("Bye!")
        break
    
    # Add user message to history
    conversation.append({
        "role": "user",
        "content": user_input
    })
    
    # Send full conversation to model
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=conversation,
        temperature=0.7
    )
    
    reply = response.choices[0].message.content
    
    # Add AI reply to history
    conversation.append({
        "role": "assistant",
        "content": reply
    })
    
    print(f"\n🤖 Bot: {reply}\n")
# Out:
# 🤖 Chatbot ready! Type 'quit' to exit
# You:  What is fine tuning?
# 🤖 Bot: Fine-tuning is when you take a pre-trained AI model and adjust its settings to fit a specific task or dataset. Think of it like taking a bike that's already assembled and tweaking the gears to suit your local terrain.
#
# Example: You take a pre-trained language model and fine-tune it to recognize medical terms, making it better at understanding doctor-patient conversations.
# You:  Explain embeddings like I am 10
# 🤖 Bot: Imagine you have a lot of different toys, like blocks, dolls, and cars. An embedding is like a special map that shows where each toy is in a big room.
#
# Each toy gets a special set of numbers, like coordinates on the map, that say where it is. Toys that are similar, like all the cars, are close together on the map. Toys that are different, like blocks and dolls, are far apart.
#
# This map helps the computer understand what's similar and what's not, so it can make good choices. For example, if you ask the computer to find all the toys like "cars", it can look at the map and say "oh, they're all over here!"
# You:  What is the difference between GPT and Llama?
# 🤖 Bot: GPT (Generative Pre-trained Transformer) and Llama are both AI models, but they're developed by different companies.
#
# GPT is made by OpenAI, while Llama is made by Meta. They're both used for similar tasks, like answering questions and generating text, but they have some differences in how they're trained and what they're good at.
#
# Think of it like two different brands of smartphones - they both make calls and send texts, but they have some unique features and designs.
# You:  quit
# Bye!
